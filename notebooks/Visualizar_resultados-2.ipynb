# %%
from google.colab import drive
drive.mount('/content/drive')

import os

REPO_URL = "https://github.com/AngelDavid8705/Rehab_Equipo_Reto.git"
REPO_DIR = "/content/Rehab_Equipo_Reto"

if not os.path.exists(REPO_DIR):
    # !git clone {REPO_URL} {REPO_DIR}
else:
    # !cd {REPO_DIR} && git pull

# %cd {REPO_DIR}
# !pip install -q -r requirements.txt
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Updating 4a9d525..b876a97
# error: Your local changes to the following files would be overwritten by merge:
# 	results/comparacion_modelos.csv
# Please commit your changes or stash them before you merge.
# Aborting
# /content/Rehab_Equipo_Reto

# %%
DATA_DIR_DRIVE = "/content/drive/MyDrive/Reto_rehab/REHAB/Rehab_exercise/d02_processed_data"

if os.path.islink("data/raw") or os.path.exists("data/raw"):
    # !rm -rf data/raw
os.symlink(DATA_DIR_DRIVE, "data/raw")
print("archivos disponibles:", len(os.listdir("data/raw")))
# Out:
# archivos disponibles: 32

# %%
# !python src/train_models.py --csv data/rehab_features_dataset.csv --out-dir results
# Out:
# cargando dataset...
# X: (4257, 60)   y: (4257,)   clases: 15
#
# train: 2979   val: 639   test: 639 muestras
#
# entrenando y comparando modelos (con validation)...
#
# Regresion Logistica     exactitud_val=0.834  f1_macro_val=0.830  (3.7s)
# KNN (k=5)               exactitud_val=0.875  f1_macro_val=0.874  (0.0s)
# Arbol de Decision       exactitud_val=0.892  f1_macro_val=0.889  (0.6s)
# Random Forest           exactitud_val=0.959  f1_macro_val=0.958  (7.3s)
# SVM (RBF)               exactitud_val=0.958  f1_macro_val=0.956  (0.2s)
#
# comparacion (validation) guardada en results/comparacion_modelos.csv
#
# mejor modelo: Random Forest
# desempeno final en test (no usado para elegir el modelo):
#   exactitud_test=0.966  f1_macro_test=0.966
# mejor modelo guardado en results/mejor_modelo.joblib
#
# tabla de comparacion (validation):
#              modelo  exactitud_val  f1_macro_val  tiempo_entrenamiento_s
#       Random Forest         0.9593        0.9578                    7.31
# ...

# %%
# !jupyter nbconvert --to notebook --execute --inplace notebooks/eda.ipynb
print("listo")
# Out:
# [NbConvertApp] Converting notebook notebooks/eda.ipynb to notebook
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# [NbConvertApp] Writing 285860 bytes to notebooks/eda.ipynb
# listo

# %%
import shutil
from google.colab import files

shutil.make_archive("results", "zip", "results")
files.download("results.zip")

# %%
import joblib

datos = joblib.load("results/mejor_modelo.joblib")
print(datos["nombre"])
print(datos["modelo"])
print(datos["scaler"])
# Out:
# Random Forest
# RandomForestClassifier(n_estimators=300, n_jobs=-1, random_state=42)
# StandardScaler()
